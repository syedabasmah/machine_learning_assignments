# %% [markdown]
# <a href="https://colab.research.google.com/github/syedabasmah/machine_learning_assignments/blob/main/assignment04/Machine_Learning_Assignment_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assignment Instructions:**

# %% [markdown]
# Study gates implementation from the following link
# https://medium.com/@stanleydukor/neural-representation-of-and-or-not-xor-and-xnor-logic-gates-perceptron-algorithm-b0275375fea1
#
#
# and submit your implementation for XOR gate for d=3 ( inputs = 3)

# %% [markdown]
# # **Implementation of XOR Gate using TensorFlow & Keras (DL libraries)**

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([[0,0], [0,1], [1,0], [1,1]])
y = np.array([[0],[1],[1],[0]])

# %%
print(x.shape)
print(y.shape)
# Out:
# (4, 2)
# (4, 1)

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Dense(2, activation='sigmoid', input_shape=(2,)),
        tf.keras.layers.Dense(1, activation='sigmoid')])

# %%
model.compile(
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.1),
    loss = 'mse',
    metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 2)                 6
#
#  dense_9 (Dense)             (None, 1)                 3
#
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x, y, epochs = 6000, batch_size = 4)
print(model.evaluate(x,y))
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1741 - accuracy: 0.7500
# Epoch 3503/6000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1741 - accuracy: 0.7500
# Epoch 3504/6000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1741 - accuracy: 0.7500
# Epoch 3505/6000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1741 - accuracy: 0.7500
# Epoch 3506/6000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1740 - accuracy: 0.7500
# Epoch 3507/6000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1740 - accuracy: 0.7500
# Epoch 3508/6000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1740 - accuracy: 0.7500
# Epoch 3509/6000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1739 - accuracy: 0.7500
# Epoch 3510/6000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1739 - accuracy: 0.7500
# Epoch 3511/6000
# ...

# %%
print(model.predict(x))
print(np.round(model.predict(x)))
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f85ee63f7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[0.149842 ]
#  [0.7661315]
#  [0.7664771]
#  [0.2797742]]
# [[0.]
#  [1.]
#  [1.]
#  [0.]]

# %%
for weight in model.weights:
  print(weight)
# Out:
# <tf.Variable 'dense_8/kernel:0' shape=(2, 2) dtype=float32, numpy=
# array([[ 2.2675707, -4.6249766],
#        [ 2.2949398, -4.7651167]], dtype=float32)>
# <tf.Variable 'dense_8/bias:0' shape=(2,) dtype=float32, numpy=array([-3.4172378,  1.161912 ], dtype=float32)>
# <tf.Variable 'dense_9/kernel:0' shape=(2, 1) dtype=float32, numpy=
# array([[-4.4250007],
#        [-5.262225 ]], dtype=float32)>
# <tf.Variable 'dense_9/bias:0' shape=(1,) dtype=float32, numpy=array([2.4128332], dtype=float32)>

# %%
import matplotlib.pyplot as plt 

plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Model Loss')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Model Accuracy')
plt.show()
